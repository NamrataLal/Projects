# %% [markdown]
# # Task
#
# Using the dataset with raw data containing over 31,000 medals (summer.csv) and the official Medal Tables for the Editions 1996 and 1976 from Wikipedia. (wik_1996.csv, wik_1976.csv). Using the two official Medal Tables as a reference to check for the correct output.
#
# The goal is to minimize the divergence between the aggregated Medal Tables and the official Medal Tables.

# %%
import pandas as pd     #importing pandas and numpy library for preparing the data 
import numpy as np

# %%
summer = pd.read_csv('summer.csv')      #reading the raw dataset and the official medal tables from wikipedia
wik_1996 = pd.read_csv('wik_1996.csv')
wik_1976 = pd.read_csv('wik_1976.csv')

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %%
summer[summer.isna().any(axis = 1)]    #checking for null values across the columns
# Out:
#        Year    City          Sport           Discipline          Athlete  \
# 29603  2012  London      Athletics            Athletics          Pending
# 31072  2012  London  Weightlifting        Weightlifting          Pending
# 31091  2012  London  Weightlifting        Weightlifting          Pending
# 31110  2012  London      Wrestling  Wrestling Freestyle  KUDUKHOV, Besik
#
#       Country Gender     Event   Medal
# 29603     NaN  Women     1500M    Gold
# 31072     NaN  Women      63KG    Gold
# 31091     NaN    Men      94KG  Silver
# 31110     NaN    Men  Wf 60 KG  Silver

# %%
summer.dropna(inplace = True)   #dropping the null values

# %%
wik_1976.head()
# Out:
#   Rank                  NOC  Gold  Silver  Bronze  Total
# 0    1   Soviet Union (URS)    49      41      35    125
# 1    2   East Germany (GDR)    40      25      25     90
# 2    3  United States (USA)    34      35      25     94
# 3    4   West Germany (FRG)    10      12      17     39
# 4    5          Japan (JPN)     9       6      10     25

# %%
wik_1996.head()
# Out:
#   Rank                Nation  Gold  Silver  Bronze  Total
# 0    1  United States (USA)*    44      32      25    101
# 1    2          Russia (RUS)    26      21      16     63
# 2    3         Germany (GER)    20      18      27     65
# 3    4           China (CHN)    16      22      12     50
# 4    5          France (FRA)    15       7      15     37

# %%
wik_1976.NOC.str.split('(', expand = True).iloc[:, 1].str.replace(')', '').str.replace('*','')
# Out:
# 0         URS
# 1         GDR
# 2         USA
# 3         FRG
# 4         JPN
# 5         POL
# 6         BUL
# 7         CUB
# 8         ROU
# 9         HUN
# 10        FIN
# 11        SWE
# 12        GBR
# 13        ITA
# 14        FRA
# 15        YUG
# 16        TCH
# 17        NZL
# 18        KOR
# 19        SUI
# 20        JAM
# 21        PRK
# 22        NOR
# 23        DEN
# 24        MEX
# 25        TRI
# 26        CAN
# 27        BEL
# 28        NED
# 29        POR
# 30        ESP
# 31        AUS
# 32        IRI
# 33        MGL
# 34        VEN
# 35        BRA
# 36        AUT
# 37        BER
# 38        PAK
# 39        PUR
# 40        THA
# 41    41 NOCs
# Name: 1, dtype: object

# %%
wik_1976['Country'] = wik_1976.NOC.str.split('(', expand = True).iloc[:, 1].str.replace(')', '').str.replace('*','')

# %%
wik_1976 = wik_1976.drop(columns = ['Rank','NOC','Total']).set_index('Country')
wik_1976.head()
# Out:
#          Gold  Silver  Bronze
# Country
# URS        49      41      35
# GDR        40      25      25
# USA        34      35      25
# FRG        10      12      17
# JPN         9       6      10

# %%
wik_1996['Country'] = wik_1996.Nation.str.split('(', expand = True).iloc[:,1].str.replace(')', '').str.replace('*','')
wik_1996 = wik_1996.drop(columns = ['Rank','Nation','Total']).set_index('Country')
wik_1996.head()
# Out:
#          Gold  Silver  Bronze
# Country
# USA        44      32      25
# RUS        26      21      16
# GER        20      18      27
# CHN        16      22      12
# FRA        15       7      15

# %% [markdown]
# Creating the column Event_Gender and identifying the mixed gender events(inputs from the experts)

# %% [markdown]
# All the events containg mixed,pairs,equestrian and sailing (before 1988) in the column are considered mixed events.

# %%
summer['Event_Gender'] = summer.Gender
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_Gender
# 0              100M Freestyle    Gold          Men
# 1              100M Freestyle  Silver          Men
# 2  100M Freestyle For Sailors  Bronze          Men
# 3  100M Freestyle For Sailors    Gold          Men
# 4  100M Freestyle For Sailors  Silver          Men

# %%
summer.Event.str.lower().str.contains('mixed').sum()
# Out:
# 38

# %%
summer.Event.str.lower().str.contains('pairs').sum()
# Out:
# 12

# %%
summer.Event.str.lower().str.contains('equestrian').sum()
# Out:
# 0

# %%
((summer.Sport.str.lower().str.contains('sailing')) & (summer.Year < 1988)).sum()
# Out:
# 755

# %%
mask1 = summer.Event.str.lower().str.contains('mixed')
mask2 = summer.Event.str.lower().str.contains('pairs')
mask3 = summer.Sport.str.lower().str.contains('equestrian')
mask4 = ((summer.Sport.str.lower().str.contains('sailing')) & (summer.Year < 1988)).sum()

# %%
summer.loc[mask1 | mask2 | mask3 | mask4 , 'Event_Gender'] = 'X'
summer.Event_Gender.value_counts()
# Out:
# X    31161
# Name: Event_Gender, dtype: int64

# %% [markdown]
# Medals awarded in Badminton mixed Double Events

# %%
badm_mixed = [21773, 21782, 21776,21785, 21770, 21779,23703,23712,23706, 23715,23709,23700,25720,25729,25723,25732,25726,
              25717,27727,27736, 27730,27739,27724,27733, 29784, 29785,29786,29787,29788,29789]

# %%
summer.loc[badm_mixed, "Event_Gender"] = "X"

# %% [markdown]
# # Identifying unique events

# %%
summer["Event_Medals"] = summer.groupby(["Year", "Sport", "Discipline", "Event", "Event_Gender"]).Medal.transform("count")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_Gender  Event_Medals
# 0              100M Freestyle    Gold            X             2
# 1              100M Freestyle  Silver            X             2
# 2  100M Freestyle For Sailors  Bronze            X             3
# 3  100M Freestyle For Sailors    Gold            X             3
# 4  100M Freestyle For Sailors  Silver            X             3

# %%
summer.Event_Medals.value_counts().sort_index()
# Out:
# 1         3
# 2        44
# 3      5502
# 4      1564
# 5        40
#        ...
# 98      196
# 104     104
# 108     216
# 110     110
# 116     116
# Name: Event_Medals, Length: 78, dtype: int64

# %%
summer.loc[summer.Event_Medals == 5]
# Out:
#        Year       City       Sport    Discipline                     Athlete  \
# 1273   1908     London   Athletics     Athletics     ARCHIBALD, Edward Blake
# 1274   1908     London   Athletics     Athletics     JACOBS, Charles Sherman
# 1275   1908     London   Athletics     Athletics           SÖDERSTRÖM, Bruno
# 1276   1908     London   Athletics     Athletics        COOKE, Edward Tiffin
# 1277   1908     London   Athletics     Athletics    GILBERT, Alfred Carleten
# 7770   1948     London  Gymnastics   Artistic G.     MOGYOROSI-KLENCS, Janos
# 7771   1948     London  Gymnastics   Artistic G.              PATAKI, Ferenc
# 7772   1948     London  Gymnastics   Artistic G.               SOTORNIK, Leo
# 7773   1948     London  Gymnastics   Artistic G.    AALTONEN, Paavo Johannes
# 7774   1948     London  Gymnastics   Artistic G.          ROVE, Olavi Antero
# 15748  1980     Moscow  Equestrian      Eventing                     PINTSET
# 15749  1980     Moscow  Equestrian      Eventing              SALNIKOV, Yuri
# 15750  1980     Moscow  Equestrian      Eventing        ROMAN, Federico Euro
# 15751  1980     Moscow  Equestrian      Eventing           BLINOV, Aleksandr
# 15752  1980     Moscow  Equestrian      Eventing                      GALZUN
# 15976  1980     Moscow  Gymnastics   Artistic G.             FILATOVA, Maria
# 15977  1980     Moscow  Gymnastics   Artistic G.              KRÄKER, Steffi
# 15978  1980     Moscow  Gymnastics   Artistic G.                RÜHN, Melita
# 15979  1980     Moscow  Gymnastics   Artistic G.                GNAUCK, Maxi
# 15980  1980     Moscow  Gymnastics   Artistic G.              EBERLE, Emilia
# 20539  1992  Barcelona  Gymnastics   Artistic G.                 GUO, Linyao
# 20540  1992  Barcelona  Gymnastics   Artistic G.          KOROBCHINSKI, Igor
# 20541  1992  Barcelona  Gymnastics   Artistic G.         MATSUNAGA, Masayuki
# 20542  1992  Barcelona  Gymnastics   Artistic G.             SCHERBO, Vitaly
# 20543  1992  Barcelona  Gymnastics   Artistic G.                    LI, Jing
# 22326  1996    Atlanta  Gymnastics   Artistic G.                    FAN, Bin
# 22327  1996    Atlanta  Gymnastics   Artistic G.               NEMOV, Alexei
# 22328  1996    Atlanta  Gymnastics   Artistic G.             SCHERBO, Vitaly
# 22329  1996    Atlanta  Gymnastics   Artistic G.             WECKER, Andreas
# 22330  1996    Atlanta  Gymnastics   Artistic G.  DOUNEV, Krassimir Nikolaev
# 28024  2008    Beijing     Cycling  Cycling Road          CANCELLARA, Fabian
# 28025  2008    Beijing     Cycling  Cycling Road             SANCHEZ, Samuel
# 28026  2008    Beijing     Cycling  Cycling Road            GUDERZO, Tatiana
# 28027  2008    Beijing     Cycling  Cycling Road               COOKE, Nicole
# 28028  2008    Beijing     Cycling  Cycling Road             JOHANSSON, Emma
# 29600  2012     London   Athletics     Athletics          MAKHLOUFI, Taoufik
# 29601  2012     London   Athletics     Athletics             MANZANO, Leonel
# 29602  2012     London   Athletics     Athletics          IGUIDER, Abdalaati
# 29604  2012     London   Athletics     Athletics                BULUT, Gamze
# 29605  2012     London   Athletics     Athletics         JAMAL, Maryam Yusuf
#
#       Country Gender                 Event   Medal Event_Gender  Event_Medals
# 1273      CAN    Men            Pole Vault  Bronze            X             5
# 1274      USA    Men            Pole Vault  Bronze            X             5
# 1275      SWE    Men            Pole Vault  Bronze            X             5
# 1276      USA    Men            Pole Vault    Gold            X             5
# 1277      USA    Men            Pole Vault    Gold            X             5
# 7770      HUN    Men                 Vault  Bronze            X             5
# 7771      HUN    Men                 Vault  Bronze            X             5
# 7772      TCH    Men                 Vault  Bronze            X             5
# 7773      FIN    Men                 Vault    Gold            X             5
# 7774      FIN    Men                 Vault  Silver            X             5
# 15748     URS    Men            Individual  Bronze            X             5
# 15749     URS    Men            Individual  Bronze            X             5
# 15750     ITA    Men            Individual    Gold            X             5
# 15751     URS    Men            Individual  Silver            X             5
# 15752     URS    Men            Individual  Silver            X             5
# 15976     URS  Women           Uneven Bars  Bronze            X             5
# 15977     GDR  Women           Uneven Bars  Bronze            X             5
# 15978     ROU  Women           Uneven Bars  Bronze            X             5
# 15979     GDR  Women           Uneven Bars    Gold            X             5
# 15980     ROU  Women           Uneven Bars  Silver            X             5
# 20539     CHN    Men         Parallel Bars  Bronze            X             5
# 20540     EUN    Men         Parallel Bars  Bronze            X             5
# 20541     JPN    Men         Parallel Bars  Bronze            X             5
# 20542     EUN    Men         Parallel Bars    Gold            X             5
# 20543     CHN    Men         Parallel Bars  Silver            X             5
# 22326     CHN    Men        Horizontal Bar  Bronze            X             5
# 22327     RUS    Men        Horizontal Bar  Bronze            X             5
# 22328     BLR    Men        Horizontal Bar  Bronze            X             5
# 22329     GER    Men        Horizontal Bar    Gold            X             5
# 22330     BUL    Men        Horizontal Bar  Silver            X             5
# 28024     SUI    Men  Individual Road Race  Bronze            X             5
# 28025     ESP    Men  Individual Road Race    Gold            X             5
# 28026     ITA  Women  Individual Road Race  Bronze            X             5
# 28027     GBR  Women  Individual Road Race    Gold            X             5
# 28028     SWE  Women  Individual Road Race  Silver            X             5
# 29600     ALG    Men                 1500M    Gold            X             5
# 29601     USA    Men                 1500M  Silver            X             5
# 29602     MAR    Men                 1500M  Bronze            X             5
# 29604     TUR  Women                 1500M  Silver            X             5
# 29605     BRN  Women                 1500M  Bronze            X             5

# %% [markdown]
# # Identifying Team Events

# %% [markdown]
# All medals / rows, that were awarded in Events with more than 5 medals, shall be deemed Team Event Medals. (new column "Team")

# %%
summer["Team"] = pd.Series(np.where(summer.Event_Medals > 5, "Yes", "No"))

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal Event_Gender  Event_Medals Team
# 0              100M Freestyle    Gold            X             2   No
# 1              100M Freestyle  Silver            X             2   No
# 2  100M Freestyle For Sailors  Bronze            X             3   No
# 3  100M Freestyle For Sailors    Gold            X             3   No
# 4  100M Freestyle For Sailors  Silver            X             3   No

# %%
summer.Team.value_counts()
# Out:
# Yes    24008
# No      7149
# Name: Team, dtype: int64

# %%
#Removing duplicated Medals in Team Events
summer.reset_index(inplace=True)
summer.head()
# Out:
#    level_0  index  Year    City     Sport Discipline             Athlete  \
# 0        0      0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred
# 1        1      1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto
# 2        2      2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios
# 3        3      3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis
# 4        4      4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon
#
#   Country Gender                       Event   Medal Event_Gender  \
# 0     HUN    Men              100M Freestyle    Gold            X
# 1     AUT    Men              100M Freestyle  Silver            X
# 2     GRE    Men  100M Freestyle For Sailors  Bronze            X
# 3     GRE    Men  100M Freestyle For Sailors    Gold            X
# 4     GRE    Men  100M Freestyle For Sailors  Silver            X
#
#    Event_Medals Team
# 0             2   No
# 1             2   No
# 2             3   No
# 3             3   No
# 4             3   No

# %%
singles = summer.loc[summer.Team == "No"].copy()
singles.shape
# Out:
# (7149, 14)

# %%
team = summer.loc[summer.Team == "Yes"].copy()
team.shape
# Out:
# (24008, 14)

# %%
team.drop_duplicates(subset = ["Year", "Sport", "Discipline", "Country", "Event", "Event_Gender", "Medal"], inplace = True)

# %%
team.shape
# Out:
# (7051, 14)

# %%
pd.concat([singles, team]).shape
# Out:
# (14200, 14)

# %%
summer_new = pd.concat([singles, team])

# %%
summer_new.set_index("index", inplace= True)

# %%
summer_new.head()
# Out:
#        level_0  Year    City     Sport Discipline             Athlete Country  \
# index
# 0            0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN
# 1            1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT
# 2            2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE
# 3            3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE
# 4            4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE
#
#       Gender                       Event   Medal Event_Gender  Event_Medals  \
# index
# 0        Men              100M Freestyle    Gold            X             2
# 1        Men              100M Freestyle  Silver            X             2
# 2        Men  100M Freestyle For Sailors  Bronze            X             3
# 3        Men  100M Freestyle For Sailors    Gold            X             3
# 4        Men  100M Freestyle For Sailors  Silver            X             3
#
#       Team
# index
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No

# %%
summer_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14200 entries, 0 to 31105
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   level_0       14200 non-null  int64
#  1   Year          14200 non-null  int64
#  2   City          14200 non-null  object
#  3   Sport         14200 non-null  object
#  4   Discipline    14200 non-null  object
#  5   Athlete       14200 non-null  object
#  6   Country       14200 non-null  object
#  7   Gender        14200 non-null  object
#  8   Event         14200 non-null  object
#  9   Medal         14200 non-null  object
#  10  Event_Gender  14200 non-null  object
#  11  Event_Medals  14200 non-null  int64
#  12  Team          14200 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 1.5+ MB

# %%
#Creating Official Medal Table
medal_tables = summer_new.groupby(["Year", "Country", "Medal"]).Medal.count().unstack(fill_value = 0)[["Gold", "Silver", "Bronze"]]
medal_tables
# Out:
# Medal         Gold  Silver  Bronze
# Year Country
# 1896 AUS         2       0       0
#      AUT         2       1       2
#      DEN         1       2       3
#      FRA         5       4       2
#      GBR         2       3       2
# ...            ...     ...     ...
# 2012 UGA         1       0       0
#      UKR         6       4       9
#      USA        38      26      27
#      UZB         1       0       2
#      VEN         1       0       0
#
# [1157 rows x 3 columns]

# %% [markdown]
# # Comparing with Wikipedia Medal Tables

# %%
medal_tables.head()
# Out:
# Medal         Gold  Silver  Bronze
# Year Country
# 1896 AUS         2       0       0
#      AUT         2       1       2
#      DEN         1       2       3
#      FRA         5       4       2
#      GBR         2       3       2

# %%
agg_1976 = medal_tables.loc[1976].sort_values(["Gold", "Silver", "Bronze"], ascending = False).copy()

# %%
agg_1976.head()
# Out:
# Medal    Gold  Silver  Bronze
# Country
# URS        46      38      33
# GDR        39      25      24
# USA        32      32      24
# FRG        10      12      17
# JPN         9       6      10

# %%
wik_1976.head()
# Out:
#          Gold  Silver  Bronze
# Country
# URS        49      41      35
# GDR        40      25      25
# USA        34      35      25
# FRG        10      12      17
# JPN         9       6      10

# %%
div_76 = agg_1976.sub(wik_1976).abs().dropna()
div_76
# Out:
# Medal    Gold  Silver  Bronze
# Country
# AUS       0.0     0.0     0.0
# AUT       0.0     0.0     0.0
# BEL       0.0     0.0     0.0
# BER       0.0     0.0     0.0
# BRA       0.0     0.0     0.0
# BUL       0.0     0.0     0.0
# CAN       0.0     0.0     0.0
# CUB       0.0     0.0     0.0
# DEN       0.0     0.0     0.0
# ESP       0.0     0.0     0.0
# FIN       0.0     0.0     0.0
# FRA       0.0     0.0     0.0
# FRG       0.0     0.0     0.0
# GBR       0.0     0.0     0.0
# GDR       1.0     0.0     1.0
# HUN       0.0     0.0     0.0
# IRI       0.0     0.0     0.0
# ITA       0.0     0.0     0.0
# JAM       0.0     0.0     0.0
# JPN       0.0     0.0     0.0
# KOR       0.0     0.0     0.0
# MEX       0.0     0.0     0.0
# MGL       0.0     0.0     0.0
# NED       0.0     0.0     0.0
# NOR       0.0     0.0     0.0
# NZL       0.0     0.0     0.0
# PAK       0.0     0.0     0.0
# POL       0.0     0.0     0.0
# POR       0.0     0.0     0.0
# PRK       0.0     0.0     0.0
# PUR       0.0     0.0     0.0
# ROU       0.0     0.0     0.0
# SUI       0.0     0.0     0.0
# SWE       0.0     0.0     0.0
# TCH       0.0     0.0     0.0
# THA       0.0     0.0     0.0
# TRI       0.0     0.0     0.0
# URS       3.0     3.0     2.0
# USA       2.0     3.0     1.0
# VEN       0.0     0.0     0.0
# YUG       0.0     0.0     0.0

# %%
score_76 = div_76.sum().sum()
score_76
# Out:
# 16.0

# %%
agg_1996 = medal_tables.loc[1996].sort_values(["Gold", "Silver", "Bronze"], ascending = False).copy()
agg_1996.head()
# Out:
# Medal    Gold  Silver  Bronze
# Country
# USA        37      29      23
# RUS        26      21      16
# GER        18      17      26
# FRA        15       6      15
# CHN        13      21      11

# %%
wik_1996.head()
# Out:
#          Gold  Silver  Bronze
# Country
# USA        44      32      25
# RUS        26      21      16
# GER        20      18      27
# CHN        16      22      12
# FRA        15       7      15

# %%
div_96 = agg_1996.sub(wik_1996).abs().dropna()
div_96
# Out:
# Medal    Gold  Silver  Bronze
# Country
# ALG       0.0     0.0     0.0
# ARG       0.0     0.0     0.0
# ARM       0.0     0.0     0.0
# AUS       0.0     0.0     3.0
# AUT       0.0     0.0     0.0
# ...       ...     ...     ...
# UKR       0.0     0.0     0.0
# USA       7.0     3.0     2.0
# UZB       0.0     0.0     0.0
# YUG       0.0     0.0     0.0
# ZAM       0.0     0.0     0.0
#
# [79 rows x 3 columns]

# %%
score_96 = div_96.sum().sum()
score_96
# Out:
# 34.0

# %%
print(score_76, score_96)
# Out:
# 16.0 34.0
